# %% [markdown]
# # 가상화폐 시세 판단하기

# %% [markdown]
# > 최고가와 최저가의 차이를 변동폭으로 정의할 때 (시가 + 변동폭)이 최고가 보다 높을 경우 "상승장", 그렇지 않은 경우 "하락장" 문자열을 출력하라.
#
# |Key Name        |     Description|
# |---|---|
# |opeing_price    |최근 24시간 내 시작 거래금액|
# |closing_price   |최근 24시간 내 마지막 거래금액|
# |min_price       |최근 24시간 내 최저 거래금액|
# |max_price       |최근 24시간 내 최고 거래금액|

# %%
import requests
from pprint import pprint
btc = requests.get('https://api.bithumb.com/public/ticker/btc').json()['data']
print(btc)
# Out:
# {'opening_price': '4474000', 'closing_price': '4490000', 'min_price': '4404000', 'max_price': '4573000', 'average_price': '4491570.4837', 'units_traded': '17387.77744698', 'volume_1day': '17387.77744698', 'volume_7day': '140801.43539124', 'buy_price': '4487000', 'sell_price': '4490000', '24H_fluctate': '16000', '24H_fluctate_rate': '0.35', 'date': '1547021894370'}

# %%
def my_nul(num):
    a = 1
    for i in range(len(num)):
        a *= i
    return a
my_nul(3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-aee3c43069dd> in <module>
#       4         a *= i
#       5     return a
# ----> 6 my_nul(3)
#
# <ipython-input-5-aee3c43069dd> in my_nul(num)
#       1 def my_nul(num):
#       2     a = 1
# ----> 3     for i in range(len(num)):
#       4         a *= i
#       5     return a
#
# TypeError: object of type 'int' has no len()

# %%
# 아래에 코드를 작성하세요.
btc
# Out:
# {'opening_price': '4305000',
#  'closing_price': '4285000',
#  'min_price': '4250000',
#  'max_price': '4339000',
#  'average_price': '4301936.8273',
#  'units_traded': '18160.13816612',
#  'volume_1day': '18160.13816612',
#  'volume_7day': '56322.07366253',
#  'buy_price': '4285000',
#  'sell_price': '4286000',
#  '24H_fluctate': '-20000',
#  '24H_fluctate_rate': '-0.46',
#  'date': '1546566160787'}

# %%
siga = int(btc['opening_price'])
cha_i = int(btc['max_price'])-int(btc['min_price'])
choi_go = int(btc['max_price'])
print('상승장') if siga + cha_i > choi_go else print('하락장')
# Out:
# 상승장

# %%
# Out:
# 89000.0

# %% [markdown]
# ## 모든 가상화폐 시세 판단하기
#
#
# > currrency dictionary에 담겨있는 모든 가상화폐 거래내역을 바탕으로 출력하라.
# >
# > 예외 처리에 유의하세요.
#
#
#
# ```
# 예시 출력)
# BTC 상승장
# ETH 상승장
# DASH 상승장
# LTC 하락장
# ETC 하락장
# XRP 상승장
# BCH 상승장
# ...
# ```

# %%
currency = requests.get('https://api.bithumb.com/public/ticker/all').json()['data']
print(currency)
# Out:
# {'BTC': {'opening_price': '4306000', 'closing_price': '4285000', 'min_price': '4250000', 'max_price': '4339000', 'average_price': '4301930.3512', 'units_traded': '18145.88776612', 'volume_1day': '18145.88776612', 'volume_7day': '56322.07366253', 'buy_price': '4285000', 'sell_price': '4286000', '24H_fluctate': '-21000', '24H_fluctate_rate': '-0.48'}, 'ETH': {'opening_price': '170000', 'closing_price': '167900', 'min_price': '163500', 'max_price': '173800', 'average_price': '168201.427', 'units_traded': '581848.30973159', 'volume_1day': '581848.30973159', 'volume_7day': '1971855.520915158066552096', 'buy_price': '167900', 'sell_price': '168000', '24H_fluctate': '-2100', '24H_fluctate_rate': '-1.23'}, 'DASH': {'opening_price': '93700', 'closing_price': '90250', 'min_price': '88100', 'max_price': '93900', 'average_price': '91172.6291', 'units_traded': '3884070.80783308', 'volume_1day': '3884070.80783308', 'volume_7day': '32161494.30256987', 'buy_price': '90100', 'sell_price': '90250', '2
# ...

# %%
# 아래에 코드를 작성하세요.
pprint(currency)
# Out:
# {'ABT': {'24H_fluctate': '-3',
#          '24H_fluctate_rate': '-3.00',
#          'average_price': '103.3566',
#          'buy_price': '96',
#          'closing_price': '96.9',
#          'max_price': '115',
#          'min_price': '94.1',
#          'opening_price': '99.9',
#          'sell_price': '96.8',
#          'units_traded': '11443322.62751732',
#          'volume_1day': '11443322.62751732',
#          'volume_7day': '50105142.256895697921657788'},
#  'ADA': {'24H_fluctate': '-0.89',
#          '24H_fluctate_rate': '-1.16',
#          'average_price': '77.2478',
#          'buy_price': '75.7',
#          'closing_price': '76.4',
#          'max_price': '79.3',
#          'min_price': '75.1',
#          'opening_price': '77.3',
#          'sell_price': '76.4',
#          'units_traded': '2122751.8440801',
#          'volume_1day': '2122751.8440801',
#          'volume_7day': '39897832.84994635'},
#  'ADD': [],
#  'AE': {'24H_fluctate': '-22',
# ...

# %%
for coin_name in currency:
    for i in coin_name:
        if coin_name['']
    print(coin_name)
# Out:
#   File "<ipython-input-57-c7a32f7871c6>", line 3
#     if coin_name['']
#                     ^
# SyntaxError: invalid syntax

# %%
for key, value in currency.items():
    if type(value) == dict:
        siga = float(value['opening_price'])
        cha_i = float(value['max_price'])-float(value['min_price'])
        choi_go = float(value['max_price'])
        print(f'{key:5}상승장') if siga + cha_i > choi_go else print(f'{key:5}하락장')
# Out:
# BTC  상승장
# ETH  상승장
# DASH 상승장
# LTC  상승장
# ETC  상승장
# XRP  상승장
# BCH  상승장
# XMR  상승장
# ZEC  상승장
# QTUM 상승장
# BTG  상승장
# EOS  상승장
# ICX  상승장
# VET  상승장
# TRX  상승장
# ELF  상승장
# MITH 상승장
# MCO  상승장
# OMG  상승장
# KNC  상승장
# GNT  상승장
# ZIL  상승장
# ETHOS상승장
# PAY  상승장
# WAX  상승장
# POWR 상승장
# LRC  상승장
# GTO  상승장
# STEEM상승장
# STRAT상승장
# ZRX  상승장
# REP  상승장
# AE   상승장
# XEM  상승장
# SNT  상승장
# ADA  상승장
# PPT  상승장
# CTXC 상승장
# CMT  상승장
# THETA상승장
# WTC  상승장
# ITC  상승장
# TRUE 상승장
# ABT  상승장
# RNT  상승장
# PLY  상승장
# WAVES상승장
# LINK 하락장
# ENJ  상승장
# PST  상승장
# SALT 상승장
# RDN  상승장
# LOOM 상승장
# BHPC 상승장
# PIVX 상승장
# INS  상승장
# BCD  상승장
# BZNT 상승장
# XLM  상승장
# OCN  상승장
# BSV  상승장
# TMTG 상승장
# BAT  상승장
# WET  상승장
# XVG  상승장
# IOST 상승장
# POLY 상승장
# HC   상승장
# ROM  상승장
# AMO  상승장

# %%
# for key, value in currency.items():
#     if type(value) == type(dict()):
#         siga = float(value['opening_price'])
#         cha_i = float(value['max_price'])-float(value['min_price'])
#         choi_go = float(value['max_price'])
#         print(f'{key:5}상승장') if siga + cha_i > choi_go else print(f'{key:5}하락장')
for key, value in currency.items():
    if type(value) == type(dict()):
        siga = float(value['opening_price'])-float(value['min_price'])
        print(f'{key:5}상승장') if siga > 0 else print(f'{key:5}하락장')
